# %%
import tensorflow as tf
import numpy as np

# %%
# Parameters for model
max_len = 40
units = 128
learning_rate = 0.001
batch_size = 200
epoch = 10
temp = 0.5

# %%
def reading_of_data(file_name):
# Function to read input text file and to convert into lower letter
    text = open(file_name, 'r').read()
    return text.lower()

# %%
def Proccessing_for_Dataset(text):
# Function to convert text data into train and label fomrat
    unique_chars = list(set(text))
    len_unique_chars = len(unique_chars)

    input_chars = []
    output_char = []

    for i in range(0, len(text) - max_len, 2):
        input_chars.append(text[i:i+max_len])
        output_char.append(text[i+max_len])

    train_data = np.zeros((len(input_chars), max_len, len_unique_chars))
    target_data = np.zeros((len(input_chars), len_unique_chars))

    for i , each in enumerate(input_chars):
        for j, char in enumerate(each):
            train_data[i, j, unique_chars.index(char)] = 1
        target_data[i, unique_chars.index(output_char[i])] = 1
    return train_data, target_data, unique_chars, len_unique_chars

# %%
def RNN_LSTM_model(x, weight, bias, len_unique_chars):
# RNN model and predictions
    x = tf.transpose(x, [1, 0, 2])
    x = tf.reshape(x, [-1, len_unique_chars])
    x = tf.split(x, max_len, 0)

    cell = tf.contrib.rnn.BasicLSTMCell(units, forget_bias=1.0)
    outputs, states = tf.contrib.rnn.static_rnn(cell, x, dtype=tf.float32)
    prediction = tf.matmul(outputs[-1], weight) + bias
    return prediction

# %%
def Probability_of_sample(predicted):
# Function to extract indeces from probability array
    exp_pred = np.exp(predicted/temp)
    predicted = exp_pred / np.sum(exp_pred)
    prob = np.random.multinomial(1, predicted, 1)
    return prob

# %%
def Training_and_Generation_of_Text(train_data, target_data, unique_chars, len_unique_chars):
    
    # Initializing placeholder for input data
    x = tf.placeholder("float", [None, max_len, len_unique_chars])
    y = tf.placeholder("float", [None, len_unique_chars])
    
    # Weight inintialization 
    weight = tf.Variable(tf.random_normal([units, len_unique_chars]))
    bias = tf.Variable(tf.random_normal([len_unique_chars]))

    # Prediction using LSTM model
    prediction = RNN_LSTM_model(x, weight, bias, len_unique_chars)
    softmax = tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y)
    cost = tf.reduce_mean(softmax)
    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

    init_op = tf.global_variables_initializer()
    
    # start of tensorflow session
    sess = tf.Session()
    sess.run(init_op)

    num_batches = int(len(train_data)/batch_size)

    for i in range(epoch):
        print ("Epoch no:- {0} of {1} is generated below:".format(i+1, epoch))
        count = 0
        for _ in range(num_batches):
            train_batch, target_batch = train_data[count:count+batch_size], target_data[count:count+batch_size]
            count += batch_size
            sess.run([optimizer] ,feed_dict={x:train_batch, y:target_batch})

        # inserting a seed for generation
        seed = train_batch[:1:]

        # Seed is given as
        seed_chars = ''
        for each in seed[0]:
                seed_chars += unique_chars[np.where(each == max(each))[0][0]]
        print ("Seeding character is:", seed_chars)

        # Prediction of next 1000 characters
        for i in range(1000):
            if i > 0:
                remove_fist_char = seed[:,1:,:]
                seed = np.append(remove_fist_char, np.reshape(probabilities, [1, 1, len_unique_chars]), axis=1)
            predicted = sess.run([prediction], feed_dict = {x:seed})
            predicted = np.asarray(predicted[0]).astype('float64')[0]
            probabilities = Probability_of_sample(predicted)
            predicted_chars = unique_chars[np.argmax(probabilities)]
            seed_chars += predicted_chars
        print ('Generated Text is given below after seed character:', seed_chars)
    sess.close()

# %%
ln = len(reading_of_data("shakespeare_input.txt"))
ln
# Out:
# 4573338

# %%
#Importing input text datset in the main function    
reduced_ln = int(ln*0.12)
data = reading_of_data('shakespeare_input.txt')[:reduced_ln]
train_data, target_data, unique_chars, len_unique_chars = Proccessing_for_Dataset(data)
Training_and_Generation_of_Text(train_data, target_data, unique_chars, len_unique_chars)
# Out:
# WARNING:tensorflow:From /home/vinitkumar/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-14-e7566c2eab03>:7: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-14-e7566c2eab03>:8: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From <ipython-input-16-281712db3ef3>:16: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Epoch no:- 1 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# the faris ar the save the shast the sall the sande sall the hast and salligh aull thas and shell the there will the the wist the wall me and made thate lave the heshe courd a dead her ard aill to has theand me cand this and ifer yould good the 'list but the thers aplant to mand hes lod of the fary,
# and all mersead math fart the nour and ino to shass i ands to the so an the pureth sours mad mere the deas fall the caas in hise the have fort sald as will the fore sang the hand in the surtse far hush ar me bat the dant sa mart spatring cour hear mave lo dear his go cours and and the fare the cursele the here thaun seand hat is hare sean the gouth shand the farter thes aran si pate the sade seer shend saull ou thaur sould that my the has will dis and is whe de my sour so deat:
# haul may the wisl have thou de shers aup tay hat say and ladse his do bole so ments tou to the lave has and ead what my love that bead you fore of the camandest math sade hame cane the sou dod and and shame fred ar an
# Epoch no:- 2 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# shat whis that has shall and math a downes and hear have my ard and the mure,
# if reve the tous the murk a sunth heref in the saniten the mestend thou have the pasting there soring caint.
#
# juliet:
# the fare a heads the what the gurs i sting;
# and go this there the pais the cames of me wind for sutent
# that sie, the surse the surse the wain shall be thou have to sour and the faring,
# and the the suck of chare hear stay thou hearts
# and the reart shave hear sach the surse thee shate,
# shan the weall he no sherd i her my to beay.
#
# capulet:
# my lordse thee wheach; and whee a sour is the theer shall the will the romen will me the dist,
# and that is me the king to me the ath and with then lides me to thee frow the but so thes with me to me.
#
# rupiet:
# go, i will he wear a durse that shear ther forthous sacoust
# to sead his suple the have with me the waint
# that but the there a more deave shall the bather heveres and not for with the fare as this theero,
# is me his the day the pray to the wore, and shous,
# Epoch no:- 3 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# god there so thee speat the hate hear here sould,
# will as the word where the hear here const,
# this well them his is not is cate thee stalle soll we lien.
#
# juliet:
#
# juliet:
# gety so be shall and this say thou live so beads,
# and i hell as she will a may the browneding to her
# had.
#
# juliet:
# hourd i he the call shat thou have to bangs,
# that are shell you that to bent our not dours therr:
# and i am so love to strence ar mend in ame send,
# and all the have she cand of the soor shall.
#
# juliet:
# good thee, shall the have shall the cunsels of the spaint,
# which thou the parss the dist me come on un
# that weer shall and is the soun the thess,
# and that us a dest in the durse of thee,
# with shall my theme and where is my hears.
#
# juliet:
# go do do the days wend and you sach thee,
# if i his not sime the hare conder me that fains thee
# fares and heed the mast rend the king falle:
# there shall be shall death with may the hath,
# well the capparise the east thee then argurs
# conse the may weep to ence the daghtle and
# Epoch no:- 4 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# no, is the days my forther well the lord,
# in the pray and that the mast ther shall string
# that that the carse the dunce the cannot sour stall forsent
# that carse a seed i live the herrster thee.
#
# rames:
# o, you grief, i home friend with a ambord
# what is the surse me the candent to beent.
#
# rade capurence:
# shall we cankes do such spanter me to hiss:
# and senver that thou have a such the uncouse:
# i what what you stank i lave the couns and to be.
#
# capulet:
# shall be counts here i not to the have is dead
# that shall me the have this then be these.
#
# farse cerringe:
# where should me wear thou are shall sead sire to sher.
#
# juliet:
# i what be the dast, we thee his the partun shere,
# love is the dears this shall ferevent of him.
#
# juliet:
# make i her godse me will shell the dase the hard
# how with say that sime is the carse of here.
#
# capulet:
# thy days shall no there are counter stare.
#
# juliet:
# god, make the sead thy brawen so but be to still
# thes chall speak hath the sund read the beart
# so sor where is the
# Epoch no:- 5 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# there hend me tell me the grave of the such forter
# which a tear well me list be will my the hary,
# is that the dade the banes of the death him.
#
# juliet:
# where is the such in the graunted on there:
# thou art thou day they caured his for is;
# for the mosty this the hall the seave and seen sould
# to be that i not thee shall a this caunt
# to the meart thee have and the dause to me:
# i will me thee then the darrous with here;
# and deave me not sich to burke ther faint.
#
# juliet:
# i hear to as me the hall fand a dongs streat;
# and is the morroun sirkes this mest this:
# as i hear the day, and the romeor in thou counters:
# have shall be neght and the house wite here,
# and shall be ween the eart the round of me,
# and is my parts and the such and courses
# that is by the house thee hall the caunten,
# ther bants the say the dears to the prifust him.
#
# juliet:
# my fair, he read hath shall be the friends to sue,
# and thou shald on this chall the like and lie:
# i pain so may be to his loves ween the blood,
# which night t
# Epoch no:- 6 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# ay, come, come, the hall he is the prother
# or god her hath, i stall of the his our stuen,
# and shall the plours as the but the caunt;
# and i than the tame of the like a caint;
# i will he do the subsen and sond thee the but twee,
# that is that the counts and the crust a seet.
#
# juliet:
# what is which i will and to the bear my lies,
# that is not me then here of hear your god,
# and the caunt of the marrous stains the not
# and the mast she then my fellow; and hear,
# that caule the sunce the list of this nay.
#
# juliet:
# he's nether, sifle ame good good marry death.
#
# juliet:
# for is me that is but dear usher is thou sones
# and shall shall be a speak of the right.
#
# juliet:
# i thou hast the to uncher so dead to them?
# look as this be thee to be the thise to blady
# which is the frish upon the roush it thee,
# and glody may the cault a our a see thee.
#
# juliet:
# i have nere is that the hath the stand a rome.
#
# juliet:
# i dead that where is the mone that the love on thinks.
#
# juliet:
# thy lives is the country cours the b
# Epoch no:- 7 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# go, give me not to him the marry good
# with me the maniage here here and it in the dead;
# that is my be shall shill be nees from my ling,
# i'll be the best unout marred to god,
# or this the sumbrant the race the sould will sick,
# and the banish'd many glief is not the marry,
# to me stain the such part to chall heath,
# are i will and this ary see the badish
# of the badied good with a nother the back:
# that is the crowns of the distrent the romeo,
# what is me to the wasth and a she what is need;
# this is this mears and end thee as in the death,
# and shall will me stanger we him the seem
# to bed me to shall we say the countien
# my have tell death the couse to my thee,
# and the courted marrstate it will in the romeo,
# where is never my heart; and all the hambord:
# and all the these with him, a diend that thou death thou,
# shall not form the hard our hard to that shall!
#
# aupinius: good thee well and thee, this is me,
# that i the countient good here i have to deed.
#
# capulet:
# what is the say that there is the d
# Epoch no:- 8 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# and we will me but to me, the reast but them.
#
# rusher:
# go, i am the hard have disself the face.
#
# juliet:
# i will the gradent of the viltain'd our sade,
# and in the go such dead to make is tell.
#
# lady ance:
# me lord, so like the wash the last as a shape:
# he was the many countely fair love good son
# to that i lave the daly the shall good done,
# romeo shere a did the greas to my his as,
# with the say the counter with the marrow thee,
# here is not my land shall a this speak to him.
#
# juliet:
# a parting and our heart, and live to chatiens should her shemble him.
#
# friar laurence:
# come, i may me, no mercusing the ears to is send uncher'd
# that i hear you to pise thee have be lenged it.
#
# juliet:
# i well this prison to the many stand there of there?
#
# capulet:
# a set thee, be shall i will me the count you stand,
# shall the death good all this someth good.
#
# romeo:
# o hour shall be my this best the have beens,
# and that is the days of the country forth.
#
# juliet:
# we that thou are the farewan see the may
# that thou
# Epoch no:- 9 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# my lord, that thou art count my live a fight
# the vales and the world and the heart with the face
# to be the such a couse to her him to speak.
#
# geny liart:
# bether the reast to see shield in the more,
# that thou are the call i speak nother thee, in this love.
#
# juliet:
# i wear the sead so stand the bear the cursed it
# the rouse to thy safe by the heround prove
# the such a see the stank the warsh we there is the warrs,
# and i have bee so the warth he prisent lies.
#
# juliet:
# my lords is not the shall he is be a mant.
#
# nurse:
# here is i stands my lord, which me steel in the chances
# and there as i have we have death to expeace!
#
# capulet:
# who, is the pear to the many with the sund
# is this shall deam the proad thou shalt a say to heart,
# and frin this gards and the wards all this so tuty with me,
# i am not in the counter and there and shall will be so fee
# the canter that me not prove state the marry,
# for you am speat as such a to did thee bed;
# the friends so the day, thou wast fair death,
# i have should t
# Epoch no:- 10 of 10 is generated below:
# Seeding character is: this so sudden business.
#
# lady capulet:
#
# Generated Text is given below after seed character: this so sudden business.
#
# lady capulet:
# go, i prepare a flear the earth the are,
# as he is the death you me state that thou dreash,
# with a tume a prisping of the day, i sweet.
#
# juliet:
# go, i hear the hack was do were and so mine;
# and it string the back and her a trues,
# that hear shall be speak the hards the back to hand:
# there's of this countery stand and there?
#
# nurse:
# i am suld the man, go your great to mine!
#
# juliet:
# here is the warrd? we are the nerse then hath this shoulds.
#
# juliet:
# go, i let me this way the marrie word:
# i cannot my cause that i have are then with here
# to have to be the cousin that well truik agains
# and the counter of the undaring shall fair
# so hear a just and be so plays death thou shalt and his with speak
# to chee to the such and the banish'd his sheet,
# and thou art the cause of her the such off,
# and i this becken in his disports of benith,
# that may me the speak the send throuse to bed
# in the a make a shall of this way it so me.
#
# capulet:
# the read lies and my counsel have woend
# there of such a truis fro
